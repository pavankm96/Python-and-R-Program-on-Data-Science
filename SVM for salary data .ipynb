# %%
import pandas as pd
import numpy as np
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

# %%
data_train=pd.read_csv("Datasets/SalaryData_Train.csv")

# %%
data_test=pd.read_csv("Datasets/SalaryData_Test.csv")

# %%
import matplotlib.pyplot as plt

plt.scatter(data_train['workclass'],data_train['education'])

# %%
plt.scatter(data_test['workclass'],data_test['education'])

# %%
plt.scatter(data_train['occupation'],data_train['education'])

# %%
plt.scatter(data_test['occupation'],data_test['education'])

# %%
string_columns=["workclass","education","maritalstatus","occupation","relationship","race","sex","native"]

from sklearn import preprocessing
number = preprocessing.LabelEncoder()
for i in string_columns:
    data_train[i] = number.fit_transform(data_train[i])
    data_test[i] = number.fit_transform(data_test[i])

# %%
colnames = data_train.columns
len(colnames[0:13])
trainX = data_train[colnames[0:13]]
trainY = data_train[colnames[13]]
testX  = data_test[colnames[0:13]]
testY  = data_test[colnames[13]]

# %%
model_linear = SVC(kernel = "linear")
model_linear.fit(trainX,trainY)

# %%
from sklearn.metrics import confusion_matrix
spred_gnb = gnb.fit(trainX,trainY).predict(testX)
confusion_matrix(testY,spred_gnb)
# Out:
# array([[10759,   601],
#        [ 2491,  1209]], dtype=int64)

# %%
acuracy=(10759+1209)/(10759+601+2491+1209)
acuracy
# Out:
# 0.7946879150066402

# %%
spred_mnb = mnb.fit(trainX,trainY).predict(testX)
confusion_matrix(testY,spred_mnb)
# Out:
# array([[10891,   469],
#        [ 2920,   780]], dtype=int64)

# %%
acuracy=(10891+780)/(10891+469+2920+780)
acuracy
# Out:
# 0.7749667994687915
