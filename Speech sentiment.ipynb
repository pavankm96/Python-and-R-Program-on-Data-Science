# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
import requests
import re
from bs4 import BeautifulSoup as bs
import speech_recognition as sr
from pydub import AudioSegment
import pydub
#pydub.AudioSegment.ffmpeg = "/absolute/path/to/ffmpeg"
#pydub.AudioSegment.ffmpeg = "/absolute/Datasets/ffmpeg"
from os import path
# Out:
# C:\Users\Pavan K M\anaconda3\lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
#f=open('English_Speec_Wav.wav','x')
#song = AudioSegment.from_mp3("Datasets/Speech.mp3")
#song.export("out.wav", format="wav")  # Is the same as:
#song.export("out.wav", format="wav", codec="libvorbis")

r = sr.Recognizer()
# open the file
with sr.AudioFile('Child labour speech.wav') as source:
    # listen for the data (load audio to memory)
    audio_data = r.record(source)
    # recognize (convert from speech to text)
    text = r.recognize_google(audio_data)
    print(text)
# Out:
# good morning everyone respected principal teacher and all my dear friends I am Sandeep Kumar and I study in class 6 section a today I am feeling blessed that I got an opportunity to deliver a speech on child labour child labour is really simple matter for humanity it is a crime against humanity and truthfulness sometime we can say that child labour is defined as the work that lead to the deterioration of the country childrens are the future of any country the main reason then child labour is poverty therefore to stop child labour poverty must be controlled the another reason behind child awareness and improvement improvement of the people force them to send their walk to work to stop child Liver 52 is must be spread among people as a youth of the country we must have to come forward and fight against it if we wanted to make India a developed nation this Evil must be removed and let our children to breathe in the open air thank you so much Jay Hind Jay Bharat

# %%
with open("my Speech.txt","w",encoding='utf8') as output:
    output.write(str(text))

# %%
# Joinining all the reviews into single paragraph 
cn_rev_string = text
#cn_rev_string

# %%
# words that contained in cannon
cn_reviews_words = cn_rev_string.split(" ")
cn_reviews_words
# Out:
# ['good',
#  'morning',
#  'everyone',
#  'respected',
#  'principal',
#  'teacher',
#  'and',
#  'all',
#  'my',
#  'dear',
#  'friends',
#  'I',
#  'am',
#  'Sandeep',
#  'Kumar',
#  'and',
#  'I',
#  'study',
#  'in',
#  'class',
#  '6',
#  'section',
#  'a',
#  'today',
#  'I',
#  'am',
#  'feeling',
#  'blessed',
#  'that',
#  'I',
#  'got',
#  'an',
#  'opportunity',
#  'to',
#  'deliver',
#  'a',
#  'speech',
#  'on',
#  'child',
#  'labour',
#  'child',
#  'labour',
#  'is',
#  'really',
#  'simple',
#  'matter',
#  'for',
#  'humanity',
#  'it',
#  'is',
#  'a',
#  'crime',
#  'against',
#  'humanity',
#  'and',
#  'truthfulness',
#  'sometime',
#  'we',
#  'can',
#  'say',
#  'that',
#  'child',
#  'labour',
#  'is',
#  'defined',
#  'as',
#  'the',
#  'work',
#  'that',
#  'lead',
#  'to',
#  'the',
#  'deterioration',
#  'of',
#  'the',
#  'country',
#  'childrens',
#  'are',
#  'the',
#  'future',
#  'of',
#  'any',
#  'country',
#  'the',
#  'main',
#  'reason',
#  'then',
#  'child',
#  'labour',
#  'is',
#  'poverty',
#  'therefore',
#  'to',
#  'stop',
#  'child',
#  'labour',
#  'poverty',
#  'must',
#  'be',
#  'controlled',
#  'the',
#  'another',
#  'reason',
#  'behind',
#  'child',
#  'awareness',
#  'and',
#  'improvement',
#  'improvement',
#  'of',
#  'the',
#  'people',
#  'force',
#  'them',
#  'to',
#  'send',
#  'their',
#  'walk',
#  'to',
#  'work',
#  'to',
#  'stop',
#  'child',
#  'Liver',
#  '52',
#  'is',
#  'must',
#  'be',
#  'spread',
#  'among',
#  'people',
#  'as',
#  'a',
#  'youth',
#  'of',
#  'the',
#  'country',
#  'we',
#  'must',
#  'have',
#  'to',
#  'come',
#  'forward',
#  'and',
#  'fight',
#  'against',
#  'it',
#  'if',
#  'we',
#  'wanted',
#  'to',
#  'make',
#  'India',
#  'a',
#  'developed',
#  'nation',
#  'this',
#  'Evil',
#  'must',
#  'be',
#  'removed',
#  'and',
#  'let',
#  'our',
#  'children',
#  'to',
#  'breathe',
#  'in',
#  'the',
#  'open',
#  'air',
#  'thank',
#  'you',
#  'so',
#  'much',
#  'Jay',
#  'Hind',
#  'Jay',
#  'Bharat']

# %%
stop_words = stopwords.words('english')

with open("Datasets/stop.txt","r") as sw:
    stopwords = sw.read()

stopwords = stopwords.split("\n")

# %%
cn_reviews_words = [w for w in cn_reviews_words if not w in stopwords]
cn_reviews_words
# Out:
# ['good',
#  'morning',
#  'respected',
#  'principal',
#  'teacher',
#  'dear',
#  'friends',
#  'I',
#  'Sandeep',
#  'Kumar',
#  'I',
#  'study',
#  'class',
#  '6',
#  'section',
#  'today',
#  'I',
#  'feeling',
#  'blessed',
#  'I',
#  'opportunity',
#  'deliver',
#  'speech',
#  'child',
#  'labour',
#  'child',
#  'labour',
#  'simple',
#  'matter',
#  'humanity',
#  'crime',
#  'humanity',
#  'truthfulness',
#  'child',
#  'labour',
#  'defined',
#  'work',
#  'lead',
#  'deterioration',
#  'country',
#  'childrens',
#  'future',
#  'country',
#  'main',
#  'reason',
#  'child',
#  'labour',
#  'poverty',
#  'stop',
#  'child',
#  'labour',
#  'poverty',
#  'controlled',
#  'reason',
#  'child',
#  'awareness',
#  'improvement',
#  'improvement',
#  'people',
#  'force',
#  'send',
#  'walk',
#  'work',
#  'stop',
#  'child',
#  'Liver',
#  '52',
#  'spread',
#  'people',
#  'youth',
#  'country',
#  'forward',
#  'fight',
#  'wanted',
#  'make',
#  'India',
#  'developed',
#  'nation',
#  'Evil',
#  'removed',
#  'children',
#  'breathe',
#  'open',
#  'air',
#  'Jay',
#  'Hind',
#  'Jay',
#  'Bharat']

# %%
cn_rev_string = " ".join(cn_reviews_words)
cn_rev_string
# Out:
# 'good morning respected principal teacher dear friends I Sandeep Kumar I study class 6 section today I feeling blessed I opportunity deliver speech child labour child labour simple matter humanity crime humanity truthfulness child labour defined work lead deterioration country childrens future country main reason child labour poverty stop child labour poverty controlled reason child awareness improvement improvement people force send walk work stop child Liver 52 spread people youth country forward fight wanted make India developed nation Evil removed children breathe open air Jay Hind Jay Bharat'

# %%
# WordCloud can be performed on the string inputs. That is the reason we have combined 
# entire reviews into single paragraph
# Simple word cloud


wordcloud_cn = WordCloud(
                      background_color='black',
                      width=1800,
                      height=1400
                     ).generate(cn_rev_string)

plt.imshow(wordcloud_cn)

# %%
# positive words # Choose the path for +ve words stored in system
with open("Datasets/positive-words.txt","r") as pos:
    poswords = pos.read().split("\n")
poswords = poswords[36:]

# %%
# negative words  Choose path for -ve words stored in system
with open("Datasets/negative-words.txt","r") as neg:
    negwords = neg.read().split("\n")

negwords = negwords[37:]

# %%
cn_pos_in_pos = " ".join ([w for w in cn_reviews_words if w in poswords])
wordcloud_pos_in_pos = WordCloud(
                      background_color='black',
                      width=1800,
                      height=1400
                     ).generate(cn_pos_in_pos)

plt.imshow(wordcloud_pos_in_pos)

# %%
cn_neg_in_neg = " ".join ([w for w in cn_reviews_words if w in negwords])

wordcloud_neg_in_neg = WordCloud(
                      background_color='black',
                      width=1800,
                      height=1400
                     ).generate(cn_neg_in_neg)

plt.imshow(wordcloud_neg_in_neg)
